# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('postgres://opexfclopritrp:4ef93ab4cbaa8ad1f21cfad2b47a6554b54cef14ec20d2884739e7f1b023ce26@ec2-174-129-37-15.compute-1.amazonaws.com:5432/d25ivq51vhhbqk')

# %%
engine
# Out:
# Engine(postgres://opexfclopritrp:***@ec2-174-129-37-15.compute-1.amazonaws.com:5432/d25ivq51vhhbqk)

# %%
sql = """
SELECT name, calories
FROM foods
"""

# %%
df = pd.read_sql_query(sql, engine)

# %%
df.head()
# Out:
#                   name  calories
# 0  A&W® Diet Root Beer       0.0
# 1  A&W® Diet Root Beer       0.0
# 2  A&W® Diet Root Beer       0.0
# 3  A&W® Diet Root Beer       0.0
# 4  A&W® Diet Root Beer       0.0

# %%
sql1 = """
SELECT *
FROM categories
"""

# %%
df_categories = pd.read_sql_query(sql1, engine)

# %%
df_categories.head()
# Out:
#    id      name                 created_at                 updated_at
# 0   1    Drinks 2017-04-17 19:43:29.423043 2017-04-17 20:05:35.796750
# 1   2    Shakes 2017-04-17 19:43:29.484934 2017-04-17 20:05:35.803809
# 2   3     Sides 2017-04-17 19:43:29.648398 2017-04-17 20:05:35.809128
# 3   4  Desserts 2017-04-17 19:43:29.668462 2017-04-17 20:05:35.814921
# 4   5   Entrees 2017-04-17 19:43:29.693234 2017-04-17 20:05:35.821672

# %%
sql2 = """
SELECT *
FROM restaurants
"""

# %%
df_restaurants = pd.read_sql_query(sql2, engine)

# %%
df_restaurants.head()
# Out:
#    id                                   name                 created_at  \
# 0   1                        A&W Restaurants 2017-04-17 19:43:26.708904
# 1   2                             Applebee's 2017-04-17 19:43:30.306405
# 2   3                                 Arby's 2017-04-17 19:43:35.190138
# 3   4                  Atlanta Bread Company 2017-04-17 19:43:38.028008
# 4   5  Bojangle's Famous Chicken 'n Biscuits 2017-04-17 19:43:42.123451
#
#                   updated_at
# 0 2017-04-17 19:43:26.708904
# 1 2017-04-17 19:43:30.306405
# 2 2017-04-17 19:43:35.190138
# 3 2017-04-17 19:43:38.028008
# 4 2017-04-17 19:43:42.123451

# %%
sql = """
select * from foods where calories >= 100
order by calories
"""
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#      id                                      name  category_id  restaurant_id  \
# 0  2295                 Poppy Seed Rolls (1 roll)            3             19
# 1  3197  Cappuccino with Sugar Free Vanilla Syrup           25             30
# 2  3181    Apple Dippers with Low Fat Caramel Dip            4             30
# 3  3170                         Sweet Kernel Corn            3             29
# 4  3287                                Iced Latte           25             30
#
#    calories  fat  carbs                 created_at                 updated_at
# 0       100    3   16.0 2017-04-17 19:44:35.313885 2017-04-17 19:44:35.313885
# 1       100    5   15.0 2017-04-17 19:45:07.378692 2017-04-17 19:45:07.378692
# 2       100    0   23.0 2017-04-17 19:45:07.274214 2017-04-17 19:45:07.274214
# 3       100    0   21.0 2017-04-17 19:45:03.253618 2017-04-17 19:45:03.253618
# 4       100    6    8.0 2017-04-17 19:45:07.982477 2017-04-17 19:45:07.982477

# %%
sql = """
select * from foods f where f.calories >= 100 and f.fat>=70
order by calories, fat
"""
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#      id                              name  category_id  restaurant_id  \
# 0  1456               Bacon, 3-slices – G           17             15
# 1  1506  Chicken Apple Sausage, 2-patties           17             15
# 2  1472        Breakfast Potatoes – VG, G           17             15
# 3   199      Chocolate Chip Cookie Sundae            4              2
# 4  1588            Harvest Toast – LF, VG           17             15
#
#    calories  fat  carbs                 created_at                 updated_at
# 0       110  110  110.0 2017-04-17 19:44:16.351846 2017-04-17 19:44:16.351846
# 1       110  110  110.0 2017-04-17 19:44:16.700476 2017-04-17 19:44:16.700476
# 2       140  140  140.0 2017-04-17 19:44:16.459615 2017-04-17 19:44:16.459615
# 3       154   74  210.0 2017-04-17 19:43:34.338463 2017-04-17 19:43:34.338463
# 4       170  170  170.0 2017-04-17 19:44:17.266713 2017-04-17 19:44:17.266713

# %%
sql = """
select * from foods  where name ILIKE '%%whopper%%'
"""
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#     id                                           name  category_id  \
# 0  807                       Double Whopper® Sandwich           12
# 1  808              Double Whopper® Sandwich w/o Mayo           12
# 2  809           Double Whopper® Sandwich with Cheese           12
# 3  810  Double Whopper® Sandwich with Cheese w/o Mayo           12
# 4  842                      Mustard Whopper® Sandwich           12
#
#    restaurant_id  calories  fat  carbs                 created_at  \
# 0              7       900   57     51 2017-04-17 19:43:51.944372
# 1              7       740   39     51 2017-04-17 19:43:51.950270
# 2              7       990   65     53 2017-04-17 19:43:51.956767
# 3              7       830   47     53 2017-04-17 19:43:51.962417
# 4              7       530   23     52 2017-04-17 19:43:52.165888
#
#                   updated_at
# 0 2017-04-17 19:43:51.944372
# 1 2017-04-17 19:43:51.950270
# 2 2017-04-17 19:43:51.956767
# 3 2017-04-17 19:43:51.962417
# ...

# %%
sql = """
select * from foods  where name ILIKE '%%whopper%%'
"""
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#     id                                           name  category_id  \
# 0  807                       Double Whopper® Sandwich           12
# 1  808              Double Whopper® Sandwich w/o Mayo           12
# 2  809           Double Whopper® Sandwich with Cheese           12
# 3  810  Double Whopper® Sandwich with Cheese w/o Mayo           12
# 4  842                      Mustard Whopper® Sandwich           12
#
#    restaurant_id  calories  fat  carbs                 created_at  \
# 0              7       900   57     51 2017-04-17 19:43:51.944372
# 1              7       740   39     51 2017-04-17 19:43:51.950270
# 2              7       990   65     53 2017-04-17 19:43:51.956767
# 3              7       830   47     53 2017-04-17 19:43:51.962417
# 4              7       530   23     52 2017-04-17 19:43:52.165888
#
#                   updated_at
# 0 2017-04-17 19:43:51.944372
# 1 2017-04-17 19:43:51.950270
# 2 2017-04-17 19:43:51.956767
# 3 2017-04-17 19:43:51.962417
# ...

# %%
sql = """
select * from foods f  where f.name ILIKE '%%whopper%%'and f.calories>900
"""
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#     id                                  name  category_id  restaurant_id  \
# 0  809  Double Whopper® Sandwich with Cheese           12              7
# 1  882        Texas Double Whopper® Sandwich           12              7
# 2  883        Texas Triple Whopper® Sandwich           12              7
# 3  885              Triple Whopper® Sandwich           12              7
# 4  886     Triple Whopper® Sandwich w/o Mayo           12              7
#
#    calories  fat  carbs                 created_at                 updated_at
# 0       990   65     53 2017-04-17 19:43:51.956767 2017-04-17 19:43:51.956767
# 1      1040   69     50 2017-04-17 19:43:52.417059 2017-04-17 19:43:52.417059
# 2      1270   86     50 2017-04-17 19:43:52.422710 2017-04-17 19:43:52.422710
# 3      1140   75     51 2017-04-17 19:43:52.433704 2017-04-17 19:43:52.433704
# 4       980   57     51 2017-04-17 19:43:52.439438 2017-04-17 19:43:52.439438

# %%
sql = """
select * from foods f  where f.name ILIKE '%%whopper%%'and f.calories>900
order by f.calories DESC
"""
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#     id                                           name  category_id  \
# 0  883                 Texas Triple Whopper® Sandwich           12
# 1  887           Triple Whopper® Sandwich With Cheese           12
# 2  885                       Triple Whopper® Sandwich           12
# 3  888  Triple Whopper® Sandwich With Cheese w/o Mayo           12
# 4  882                 Texas Double Whopper® Sandwich           12
#
#    restaurant_id  calories  fat  carbs                 created_at  \
# 0              7      1270   86     50 2017-04-17 19:43:52.422710
# 1              7      1230   82     53 2017-04-17 19:43:52.447516
# 2              7      1140   75     51 2017-04-17 19:43:52.433704
# 3              7      1070   64     53 2017-04-17 19:43:52.453358
# 4              7      1040   69     50 2017-04-17 19:43:52.417059
#
#                   updated_at
# 0 2017-04-17 19:43:52.422710
# 1 2017-04-17 19:43:52.447516
# 2 2017-04-17 19:43:52.433704
# 3 2017-04-17 19:43:52.453358
# ...

# %%
sql = """
select r.name as Restaurant_Name, f.name as Food_Name, c.name as Category_Name, 
f.calories, f.fat, f.carbs 
from foods f
INNER JOIN restaurants r 
on f.restaurant_id = r.id
INNER JOIN categories c 
on f.category_id = c.id
"""
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#    restaurant_name            food_name category_name  calories  fat  carbs
# 0  A&W Restaurants  A&W® Diet Root Beer        Drinks       0.0  0.0    0.0
# 1  A&W Restaurants  A&W® Diet Root Beer        Drinks       0.0  0.0    0.0
# 2  A&W Restaurants  A&W® Diet Root Beer        Drinks       0.0  0.0    0.0
# 3  A&W Restaurants  A&W® Diet Root Beer        Drinks       0.0  0.0    0.0
# 4  A&W Restaurants  A&W® Diet Root Beer        Drinks       0.0  0.0    0.0

# %%
sql = """
select r.name as Restaurant_Name, f.name as Food_Name, c.name as Category_Name, 
f.calories, f.fat, f.carbs 
from foods f
INNER JOIN restaurants r 
on f.restaurant_id = r.id
INNER JOIN categories c 
on f.category_id = c.id
"""
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#    id      name                 created_at                 updated_at
# 0   1    Drinks 2017-04-17 19:43:29.423043 2017-04-17 20:05:35.796750
# 1   2    Shakes 2017-04-17 19:43:29.484934 2017-04-17 20:05:35.803809
# 2   3     Sides 2017-04-17 19:43:29.648398 2017-04-17 20:05:35.809128
# 3   4  Desserts 2017-04-17 19:43:29.668462 2017-04-17 20:05:35.814921
# 4   5   Entrees 2017-04-17 19:43:29.693234 2017-04-17 20:05:35.821672

# %%
df_restaurants.head()
# Out:
#    id                                   name                 created_at  \
# 0   1                        A&W Restaurants 2017-04-17 19:43:26.708904
# 1   2                             Applebee's 2017-04-17 19:43:30.306405
# 2   3                                 Arby's 2017-04-17 19:43:35.190138
# 3   4                  Atlanta Bread Company 2017-04-17 19:43:38.028008
# 4   5  Bojangle's Famous Chicken 'n Biscuits 2017-04-17 19:43:42.123451
#
#                   updated_at
# 0 2017-04-17 19:43:26.708904
# 1 2017-04-17 19:43:30.306405
# 2 2017-04-17 19:43:35.190138
# 3 2017-04-17 19:43:38.028008
# 4 2017-04-17 19:43:42.123451

# %%
sql = """
select f.name as Food_Name,  f.calories, f.carbs, f.fat, r.name as Restaurant
from foods f
INNER JOIN restaurants r 
on f.restaurant_id = r.id
where r.name ILIKE '%%wendy%%';
"""
df = pd.read_sql_query(sql, engine)
df
# Out:
#                                 food_name  calories  carbs  fat restaurant
# 0              Vanilla Frosty Waffle Cone       290     53    6    Wendy's
# 1                      Value French Fries       220     28   11    Wendy's
# 2                      Value French Fries       220     28   11    Wendy's
# 3                  Ultimate Chicken Grill       370     43    7    Wendy's
# 4                  Spicy Chicken Sandwich       510     55   20    Wendy's
# 5                   Spicy Chicken Go Wrap       330     30   16    Wendy's
# 6    Spicy Chicken Caesar Salad Half-Size       440     28   27    Wendy's
# 7              Spicy Chicken Caesar Salad       780     40   51    Wendy's
# 8             Sour Cream and Chive Potato       320     63    3    Wendy's
# 9                       Son of Baconator®       670     41   37    Wendy's
# 10                  Small Vanilla Frosty™       280     46    7    Wendy's
# ...

# %%
sql = """
select f.name as Food_Name,  f.calories, f.carbs, f.fat, r.name as Restaurant
from foods f
INNER JOIN restaurants r 
on f.restaurant_id = r.id
where r.name = 'Wendy"\'"s';
"""
df = pd.read_sql_query(sql, engine)
df
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /Users/ajinthchristudas/anaconda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# /Users/ajinthchristudas/anaconda/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#
# ProgrammingError: unterminated quoted identifier at or near ""s';
# "
# LINE 6: where r.name = 'Wendy"'"s';
#                                ^
#
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
sql = """
select f.name as Food_Name,  f.calories, f.carbs, f.fat, r.name as Restaurant, c.name as category_name
from foods f
INNER JOIN restaurants r 
on f.restaurant_id = r.id
INNER JOIN categories c 
ON c.id = f.category_id
where c.name = 'Shakes'
order by f.calories DESC
"""
df = pd.read_sql_query(sql, engine)
df.head(10)
# Out:
#                                        food_name  calories  carbs  fat  \
# 0                    Malt, Peanut Butter – Large      1350  143.0   72
# 1  Shake, Oreo® Cookie w/ Whipped Topping 24 oz.      1170  134.0   61
# 2                  Chocolate Triple Thick® Shake      1160  203.0   27
# 3     Shake, Chocolate w/ Whipped Topping 24 oz.      1150  146.0   55
# 4    Shake, Strawberry w/ Whipped Topping 24 oz.      1120  138.0   54
# 5                         Monster Malt Raspberry      1105  168.0   30
# 6                        Malt, Hot Fudge – Large      1090  165.0   38
# 7                          Malt, Caramel – Large      1080  178.0   31
# 8                        Malt, Chocolate – Large      1020  171.0   32
# 9                   Malt, Peanut Butter – Medium      1010  111.0   53
#
#                   restaurant category_name
# 0                Dairy Queen        Shakes
# 1            Jack in the Box        Shakes
# 2                 McDonald's        Shakes
# ...

# %%
df_categories.head()
# Out:
#    id      name                 created_at                 updated_at
# 0   1    Drinks 2017-04-17 19:43:29.423043 2017-04-17 20:05:35.796750
# 1   2    Shakes 2017-04-17 19:43:29.484934 2017-04-17 20:05:35.803809
# 2   3     Sides 2017-04-17 19:43:29.648398 2017-04-17 20:05:35.809128
# 3   4  Desserts 2017-04-17 19:43:29.668462 2017-04-17 20:05:35.814921
# 4   5   Entrees 2017-04-17 19:43:29.693234 2017-04-17 20:05:35.821672

# %%
sql = """
select c.name, avg(f.calories)
from categories c
INNER JOIN foods f
ON c.id = f.category_id
group by c.name
order by avg(f.calories) desc
"""
df = pd.read_sql_query(sql, engine)
df.head(10)
# Out:
#            name          avg
# 0          Ribs  1499.000000
# 1    Appetizers   807.920000
# 2       Seafood   786.090000
# 3       Burgers   755.415888
# 4       Entrees   724.778626
# 5        Pizzas   632.916667
# 6    Sandwiches   608.883197
# 7        Shakes   597.865497
# 8         Wraps   582.218750
# 9  Mexican Food   573.339286

# %%
sql = """
select r.name, max(f.calories)
from restaurants r
INNER JOIN foods f
ON r.id = f.restaurant_id
group by r.name
order by max(f.calories) desc
"""
df = pd.read_sql_query(sql, engine)
df.head(10)
# Out:
#                                     name   max
# 0  Bojangle's Famous Chicken 'n Biscuits  8820
# 1                     Corner Bakery Cafe  4220
# 2                       Joe's Crab Shack  2750
# 3                     Buffalo Wild Wings  2380
# 4                             Applebee's  2375
# 5                                Chili's  2310
# 6              Red Robin Gourmet Burgers  2090
# 7                                   FATZ  1989
# 8                          El Pollo Loco  1841
# 9                                   IHOP  1780

# %%
sql = """
select r.name, max(f.calories)
from restaurants r
INNER JOIN foods f
ON r.id = f.restaurant_id
group by r.name
order by max(f.calories) desc
"""
df = pd.read_sql_query(sql, engine)
df.head(10)
# Out:
#                                     name   max
# 0  Bojangle's Famous Chicken 'n Biscuits  8820
# 1                     Corner Bakery Cafe  4220
# 2                       Joe's Crab Shack  2750
# 3                     Buffalo Wild Wings  2380
# 4                             Applebee's  2375
# 5                                Chili's  2310
# 6              Red Robin Gourmet Burgers  2090
# 7                                   FATZ  1989
# 8                          El Pollo Loco  1841
# 9                                   IHOP  1780

# %%
df_categories.head()
# Out:
#    id      name                 created_at                 updated_at
# 0   1    Drinks 2017-04-17 19:43:29.423043 2017-04-17 20:05:35.796750
# 1   2    Shakes 2017-04-17 19:43:29.484934 2017-04-17 20:05:35.803809
# 2   3     Sides 2017-04-17 19:43:29.648398 2017-04-17 20:05:35.809128
# 3   4  Desserts 2017-04-17 19:43:29.668462 2017-04-17 20:05:35.814921
# 4   5   Entrees 2017-04-17 19:43:29.693234 2017-04-17 20:05:35.821672

# %%
sql = """
select r.name as restaurant_name, f.name as food_name, f.calories from restaurants r 
inner join foods f 
on f.restaurant_id = r.id 
inner join categories c 
on f.category_id = c.id
where c.name = 'kid''s Meals'
order by f.calories desc
"""
df = pd.read_sql_query(sql, engine)
df.head(10)
# Out:
# Empty DataFrame
# Columns: [restaurant_name, food_name, calories]
# Index: []

# %%
sql = """
select * from foods
"""
df = pd.read_sql_query(sql, engine)
df.head(10)
# Out:
#    id                                name  category_id  restaurant_id  \
# 0   1                 A&W® Diet Root Beer            1              1
# 1   2                 A&W® Diet Root Beer            1              1
# 2   3                 A&W® Diet Root Beer            1              1
# 3   4                 A&W® Diet Root Beer            1              1
# 4   5                 A&W® Diet Root Beer            1              1
# 5   6                 A&W® Diet Root Beer            1              1
# 6   7   A&W® Diet Root Beer Float (large)            2              1
# 7   8  A&W® Diet Root Beer Float (medium)            2              1
# 8   9   A&W® Diet Root Beer Float (small)            2              1
# 9  10  A&W® Diet Root Beer Freeze (large)            2              1
#
#    calories   fat  carbs                 created_at                 updated_at
# 0       0.0   0.0    0.0 2017-04-17 19:43:29.444233 2017-04-17 19:43:29.444233
# ...
